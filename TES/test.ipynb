# %%
import numpy as np

# %%
# BOOLEAN STUFF 

# Imagine you have a list of numbers representing the "Categories" of items in a small dataset:
# categories = [0, 1, 2, 0, 3, 2, 1, 0]

# Question 1: The "Bouncer" Test
# Goal: Create a list of True and False (a mask) that identifies only the zeros.

# %%
categories = np.array([0, 1, 2, 0, 3, 2, 1, 0])
mask = categories == 0
print(mask)
# Out:
# [ True False False  True False False False  True]

# %%
# Question 2: The "Either/Or" (The | Operator)
# Goal: You want to find both category 0 and category 2.

mask = (categories == 0) | (categories == 2)
print(mask)
# Out:
# [ True False  True  True False  True False  True]

# %%
# Question 3: "Opposite Day" (The ~ Operator)
# Goal: You have a mask that finds category 0. Now you want everything except category 0.

# %%
mask = categories == 0
inverted_mask = ~mask
print(inverted_mask)
# Out:
# [False  True  True False  True  True  True False]

# %%
# Question 4: The "Filter" (Applying the Mask)
# Goal: Use your mask to actually extract the data.

# Challenge: If data = ["Apple", "Banana", "Cherry", "Date"] and your mask = [True, False, True, False], what will data[mask] give you?

# %%
data = np.array(["Apple", "Banana", "Cherry", "Date"])
mask = (data == "Apple") | (data == "Cherry")
print(data[~mask])
# Out:
# ['Banana' 'Date']

# %%
# Question 5: The "Relabel" Logic
# Goal: You removed category 0. Now your labels are [1, 2, 3]. You need them to be [0, 1, 2].


y = np.array([1 , 2 ,3 ])
y = y - 1
y
# Out:
# array([0, 1, 2])

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.datasets import load_nfl

# Load a clustering dataset
X, y = load_nfl()

# Specify the features to use for clustering
features = ['Rec', 'Yds', 'TD', 'Fmb', 'Ctch_Rate']
X = X.query('Tgt >= 20')[features]

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=5 , n_init=10)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# Cell In[4], line 15
#      13 # Instantiate the clustering model and visualizer
#      14 model = KMeans(n_clusters=5 , n_init=10)
# ---> 15 visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
#      17 visualizer.fit(X)        # Fit the data to the visualizer
#      18 visualizer.show()        # Finalize and render the figure
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/yellowbrick/cluster/silhouette.py:118, in SilhouetteVisualizer.__init__(self, estimator, ax, colors, is_fitted, **kwargs)
#     115 def __init__(self, estimator, ax=None, colors=None, is_fitted="auto", **kwargs):
#     116
#     117     # Initialize the visualizer bases
# --> 118     super(SilhouetteVisualizer, self).__init__(estimator, ax=ax, **kwargs)
#     120     # Visual Properties
# ...
