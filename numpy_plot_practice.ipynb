# %%
import numpy as np

# %%
np_array_one = np.array([1,2,3,4,5])
np_array_two = np.array([6,7,8,9,10])

np_combined = np.c_[np_array_two , np_array_one]
np_yeah = np_array_two + np_array_one

np_combined , np_yeah
# Out:
# (array([[ 6,  1],
#         [ 7,  2],
#         [ 8,  3],
#         [ 9,  4],
#         [10,  5]]),
#  array([ 7,  9, 11, 13, 15]))

# %%
print(np_array_one[0:5:2])
# Out:
# [1 3 5]

# %%
list_ = list(np_array_one)

print(list[0:5:2])

#fuck this shit am out no thanks
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 list_ = list(np_array_one)
#       3 print(list[0:5:2])
#
# TypeError: 'list' object is not callable

# %%
np_array_one.shape
# Out:
# (5,)

# %%
np_array_one.reshape(1,5)
# Out:
# array([[1, 2, 3, 4, 5]])

# %%
np_array_one.shape
# Out:
# (5,)
